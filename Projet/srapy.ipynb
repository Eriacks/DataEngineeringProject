# %%
import scrapy

# %%
# !scrapy startproject esf
# Out:
# New Scrapy project 'esf', using template directory '/home/valenceb/.local/lib/python3.8/site-packages/scrapy/templates/project', created in:
#     /home/valenceb/4201C/6Evaluation/Projet/esf
#
# You can start your first spider with:
#     cd esf
#     scrapy genspider example example.com

# %%
# !cd esf && scrapy genspider esf1 https://www.esf.net/
# Out:
# Created spider 'esf1' using template 'basic' in module:
#   esf.spiders.esf1

# %%
# !cd esf/esf/spiders && scrapy runspider esf1.py
# Out:
# 2024-01-18 15:26:50 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: esf)
# 2024-01-18 15:26:50 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.10 (default, Nov 22 2023, 10:22:35) - [GCC 9.4.0], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Linux-5.15.0-91-generic-x86_64-with-glibc2.29
# 2024-01-18 15:26:50 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-18 15:26:50 [asyncio] DEBUG: Using selector: EpollSelector
# 2024-01-18 15:26:50 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-18 15:26:50 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-01-18 15:26:50 [scrapy.extensions.telnet] INFO: Telnet Password: 345a335c3ac90707
# 2024-01-18 15:26:50 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-18 15:26:50 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'esf',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'esf.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['esf.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-01-18 15:26:50 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-18 15:26:50 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-18 15:26:50 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-18 15:26:50 [scrapy.core.engine] INFO: Spider opened
# 2024-01-18 15:26:50 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-18 15:26:50 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2024-01-18 15:26:50 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://technique.esf.net/robots.txt> (referer: None)
# 2024-01-18 15:26:51 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://technique.esf.net/resultat/classement.php> (referer: None)
# Nom: BARATEAU JORIS
# Code: FFS2695108
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 76
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: BARBIER LUCAS
# Code: FFS2686883
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: 91
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: BERQUET ARTHUR
# Code: ESF1030500045
# Sexe: M
# Catégorie: SH
# Nationalité: FRA
# Points: 3.85
# Département: 51
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CASTERAN ROBIN
# Code: FFS2676256
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: 38
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CHAMOUX HUGO
# Code: FFS2674503
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CHARRIER EMILIEN
# Code: FFS2675938
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CLEAK HERNANDEZ MATTEO
# Code: FFS2708577
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 74
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CORNILLON MAHE
# Code: FFS2689182
# Sexe: M
# Catégorie: U16
# Nationalité: FRA
# Points: 3.85
# Département: 73
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: COSTARD PIERRE
# Code: FFS2662034
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 69
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: COX JACK
# Code: FFS2701188
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: CUVEX-COMBAZ FELIX
# Code: FFS2656337
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 73
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: DEBUS ROMAIN
# Code: FFS2661009
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 38
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: DECLINAND ANGE
# Code: FFS2679886
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 69
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: DUPONT TIMEO
# Code: FFS2662087
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 73
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: DUTRIEVOZ ZÉPHYRIN
# Code: FFS2686381
# Sexe: M
# Catégorie: U16
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: FARIN ALBAN
# Code: FFS2644619
# Sexe: M
# Catégorie: SH
# Nationalité: FRA
# Points: 3.85
# Département: 88
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: FAVETTA LEO
# Code: FFS2665715
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: 73
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: FAVIER JEAN
# Code: FFS2667908
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: 05
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: GIRARD NATHAN
# Code: FFS2680899
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 91
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: HERVET TITOUAN
# Code: ESF1449400178
# Sexe: M
# Catégorie: U18
# Nationalité: FRA
# Points: 3.85
# Département: 92
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: JOLIET PAUL
# Code: FFS2656224
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 04
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: LACROIX VICTOR
# Code: FFS2709769
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: LAFOND SASHA
# Code: FFS2680892
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: 42
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: LAHAYE ERIC
# Code: FFS2630072
# Sexe: M
# Catégorie: SH
# Nationalité: FRA
# Points: 3.85
# Département: 01
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# Nom: LESAINT ANTOINE
# Code: FFS2696122
# Sexe: M
# Catégorie: U21
# Nationalité: FRA
# Points: 3.85
# Département: None
# Classement Général: 1/69883
# Classement Catégorie: 1/0
# Classement Nation: 1
# Classement Département: 1
# ---
# 2024-01-18 15:26:53 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-01-18 15:26:53 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 469,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 13071,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 1,
#  'downloader/response_status_count/404': 1,
#  'elapsed_time_seconds': 2.386039,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 1, 18, 14, 26, 53, 11392, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 74354,
#  'httpcompression/response_count': 1,
#  'log_count/DEBUG': 5,
#  'log_count/INFO': 10,
#  'memusage/max': 77443072,
#  'memusage/startup': 77443072,
#  'response_received_count': 2,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/404': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2024, 1, 18, 14, 26, 50, 625353, tzinfo=datetime.timezone.utc)}
# 2024-01-18 15:26:53 [scrapy.core.engine] INFO: Spider closed (finished)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 response.css("title")
#
# NameError: name 'response' is not defined
