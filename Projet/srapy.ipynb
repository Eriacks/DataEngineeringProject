# %%
import scrapy

# %%
# !scrapy startproject esf
# Out:
# New Scrapy project 'esf', using template directory '/home/valenceb/.local/lib/python3.8/site-packages/scrapy/templates/project', created in:
#     /home/valenceb/4201C/6Evaluation/Projet/esf
#
# You can start your first spider with:
#     cd esf
#     scrapy genspider example example.com

# %%
# !cd esf && scrapy genspider esf1 https://www.esf.net/
# Out:
# Created spider 'esf1' using template 'basic' in module:
#   esf.spiders.esf1

# %%
# !cd scrapy_project/esf/esf/spiders && scrapy runspider esf1.py
# Out:
# 2024-01-29 20:03:33 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: esf)
# 2024-01-29 20:03:33 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.10 (default, Nov 22 2023, 10:22:35) - [GCC 9.4.0], pyOpenSSL 23.3.0 (OpenSSL 3.1.4 24 Oct 2023), cryptography 41.0.7, Platform Linux-5.15.0-92-generic-x86_64-with-glibc2.29
# 2024-01-29 20:03:33 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-29 20:03:33 [asyncio] DEBUG: Using selector: EpollSelector
# 2024-01-29 20:03:33 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-29 20:03:33 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.unix_events._UnixSelectorEventLoop
# 2024-01-29 20:03:33 [scrapy.extensions.telnet] INFO: Telnet Password: fdca415a54512ae4
# 2024-01-29 20:03:33 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-01-29 20:03:33 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'esf',
#  'FEED_EXPORT_ENCODING': 'utf-8',
#  'NEWSPIDER_MODULE': 'esf.spiders',
#  'REQUEST_FINGERPRINTER_IMPLEMENTATION': '2.7',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_LOADER_WARN_ONLY': True,
#  'SPIDER_MODULES': ['esf.spiders'],
#  'TWISTED_REACTOR': 'twisted.internet.asyncioreactor.AsyncioSelectorReactor'}
# 2024-01-29 20:03:33 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-01-29 20:03:33 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'esf.middlewares.EsfSpiderMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-01-29 20:03:33 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-01-29 20:03:33 [scrapy.core.engine] INFO: Spider opened
# 2024-01-29 20:03:33 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-29 20:03:33 [esf1] INFO: Spider opened: esf1
# 2024-01-29 20:03:33 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-01-29 20:03:34 [scrapy.core.engine] DEBUG: Crawled (404) <GET https://www.esf.net/robots.txt> (referer: None)
# 2024-01-29 20:03:34 [protego] DEBUG: Rule at line 1 without any user agent to enforce it on.
# 2024-01-29 20:03:34 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/> (referer: None)
# 2024-01-29 20:03:34 [scrapy.dupefilters] DEBUG: Filtered duplicate request: <GET https://www.esf.net/ecole-de-ski/abondance> - no more duplicates will be shown (see DUPEFILTER_DEBUG to show all duplicates)
# 2024-01-29 20:03:35 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/abondance> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:06 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/abondance> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f687b13eda2cef3d4288, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/aime-la-plagne> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/agudes> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/amneville> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/haut-guil> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/albiez-montrond> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/les-aillons> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/allos-seignus> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:07 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/alpe-grand-serre> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:04:37 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/aime-la-plagne> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f6a7b13eda2cef3d428a, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:05:08 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/agudes> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f6c5b13eda2cef3d428c, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:05:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/amneville> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f6e4b13eda2cef3d428e, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:06:08 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/haut-guil> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f702b13eda2cef3d4290, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:06:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/albiez-montrond> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f720b13eda2cef3d4292, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:07:08 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/les-aillons> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f73eb13eda2cef3d4294, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:07:38 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/allos-seignus> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f75cb13eda2cef3d4296, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:08:09 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/alpe-grand-serre> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f77ab13eda2cef3d4298, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:08:09 [scrapy.extensions.logstats] INFO: Crawled 11 pages (at 11 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/angles> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/araches-les-carroz> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/arc1800> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/champ-du-feu> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/annecy> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/alpe-d-huez> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/arc1600> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:09 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/ancelle> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:08:39 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/angles> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f799b13eda2cef3d429a, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:09:09 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/araches-les-carroz> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f7b7b13eda2cef3d429c, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:09:39 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/arc1800> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f7d5b13eda2cef3d429e, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:10:09 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/champ-du-feu> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f7f3b13eda2cef3d42a0, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:10:40 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/annecy> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f811b13eda2cef3d42a2, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:11:10 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/alpe-d-huez> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f830b13eda2cef3d42a4, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:11:40 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/arc1600> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b7f84eb13eda2cef3d42a6, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# ...
# 2024-01-29 20:47:26 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/la-feclaz> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b800b0b13eda2cef3d4334, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:47:57 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/flaine> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b800ceb13eda2cef3d4336, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:48:27 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/foncine> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b800edb13eda2cef3d4338, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:48:27 [scrapy.extensions.logstats] INFO: Crawled 91 pages (at 8 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-29 20:48:27 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.esf.net/ecole-de-ski/sommand-mieussy> (failed 1 times): [<twisted.python.failure.Failure twisted.internet.error.ConnectionLost: Connection to the other side was lost in a non-clean fashion: Connection lost.>]
# 2024-01-29 20:48:27 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.esf.net/ecole-de-ski/st-francois-longchamp> (failed 1 times): User timeout caused connection failure: Getting https://www.esf.net/ecole-de-ski/st-francois-longchamp took longer than 180.0 seconds..
# 2024-01-29 20:48:27 [scrapy.downloadermiddlewares.retry] DEBUG: Retrying <GET https://www.esf.net/ecole-de-ski/st-colomban-des-villards> (failed 1 times): User timeout caused connection failure: Getting https://www.esf.net/ecole-de-ski/st-colomban-des-villards took longer than 180.0 seconds..
# 2024-01-29 20:48:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/st-jean-arves> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:48:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/st-lary-soulan> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:48:58 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/st-jean-arves> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b8010bb13eda2cef3d433a, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:48:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/serre-che1350> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:48:58 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/serre-che1400> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.esf.net/ecole-de-ski/st-lary-soulan> (referer: https://www.esf.net/ecole-de-ski/)
# Traceback (most recent call last):
#   File "/home/valenceb/.local/lib/python3.8/site-packages/twisted/internet/defer.py", line 892, in _runCallbacks
#     current.result = callback(  # type: ignore[misc]
#   File "/home/valenceb/4201C/6Evaluation/Projet/scrapy_project/esf/esf/spiders/esf1.py", line 68, in parse_new_url
#     collection.insert_one(document)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 669, in insert_one
#     self._insert_one(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/collection.py", line 609, in _insert_one
#     self.__database.client._retryable_write(acknowledged, _insert_command, session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1522, in _retryable_write
#     with self._tmp_session(session) as s:
#   File "/usr/lib/python3.8/contextlib.py", line 113, in __enter__
#     return next(self.gen)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1840, in _tmp_session
#     s = self._ensure_session(session)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1823, in _ensure_session
#     return self.__start_session(True, causal_consistency=False)
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/mongo_client.py", line 1766, in __start_session
#     self._topology._check_implicit_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 573, in _check_implicit_session_support
#     self._check_session_support()
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 589, in _check_session_support
#     self._select_servers_loop(
#   File "/home/valenceb/.local/lib/python3.8/site-packages/pymongo/topology.py", line 259, in _select_servers_loop
#     raise ServerSelectionTimeoutError(
# pymongo.errors.ServerSelectionTimeoutError: mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms), Timeout: 30s, Topology Description: <TopologyDescription id: 65b8012ab13eda2cef3d433c, topology_type: Unknown, servers: [<ServerDescription ('mongodb', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('mongodb:27017: [Errno -3] Temporary failure in name resolution (configured timeouts: socketTimeoutMS: 20000.0ms, connectTimeoutMS: 20000.0ms)')>]>
# 2024-01-29 20:49:28 [scrapy.extensions.logstats] INFO: Crawled 95 pages (at 4 pages/min), scraped 0 items (at 0 items/min)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/st-gervais-les-bains> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/serre-che1500> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/serre-che-briancon> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/sept-laux> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/sauze> (referer: https://www.esf.net/ecole-de-ski/)
# 2024-01-29 20:49:28 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.esf.net/ecole-de-ski/sappey-chartreuse> (referer: https://www.esf.net/ecole-de-ski/)
