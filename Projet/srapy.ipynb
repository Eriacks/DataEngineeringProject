# %%
import scrapy

# %%
# !scrapy startproject esf
# Out:
# New Scrapy project 'esf', using template directory '/home/valenceb/.local/lib/python3.8/site-packages/scrapy/templates/project', created in:
#     /home/valenceb/4201C/6Evaluation/Projet/esf
#
# You can start your first spider with:
#     cd esf
#     scrapy genspider example example.com

# %%
# !cd esf && scrapy genspider esf1 https://www.esf.net/
# Out:
# Created spider 'esf1' using template 'basic' in module:
#   esf.spiders.esf1

# %%
# !cd esf/esf/spiders && scrapy runspider esf1.py
# Out:
# 2024-01-25 15:33:11 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: esf)
# 2024-01-25 15:33:11 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 23.2.0 (OpenSSL 3.0.12 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22000-SP0
# 2024-01-25 15:33:11 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-25 15:33:11 [asyncio] DEBUG: Using selector: SelectSelector
# 2024-01-25 15:33:11 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-25 15:33:11 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2024-01-25 15:33:11 [scrapy.extensions.telnet] INFO: Telnet Password: b2da1eda9166b8a5
# 2024-01-25 15:33:11 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...

# %%
# !cd esf && scrapy genspider esf2 https://technique.clubesf.com
# Out:
# Spider 'esf2' already exists in module:
#   esf.spiders.esf2
# 'sexe' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'an_inf' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'an_sup' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'point_inf' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'point_sup' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'nation' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'cp' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.
# 'nom' n'est pas reconnu en tant que commande interne
# ...

# %%
# !cd esf/esf/spiders && scrapy runspider esf2.py
# Out:
# 2024-01-26 00:29:17 [scrapy.utils.log] INFO: Scrapy 2.11.0 started (bot: esf)
# 2024-01-26 00:29:17 [scrapy.utils.log] INFO: Versions: lxml 4.9.3.0, libxml2 2.10.3, cssselect 1.2.0, parsel 1.8.1, w3lib 2.1.2, Twisted 22.10.0, Python 3.8.18 (default, Sep 11 2023, 13:39:12) [MSC v.1916 64 bit (AMD64)], pyOpenSSL 23.2.0 (OpenSSL 3.0.12 24 Oct 2023), cryptography 41.0.7, Platform Windows-10-10.0.22000-SP0
# 2024-01-26 00:29:17 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-01-26 00:29:17 [asyncio] DEBUG: Using selector: SelectSelector
# 2024-01-26 00:29:17 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.asyncioreactor.AsyncioSelectorReactor
# 2024-01-26 00:29:17 [scrapy.utils.log] DEBUG: Using asyncio event loop: asyncio.windows_events._WindowsSelectorEventLoop
# 2024-01-26 00:29:17 [scrapy.extensions.telnet] INFO: Telnet Password: 697d10457de4ac27
# 2024-01-26 00:29:17 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# ...
